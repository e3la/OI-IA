# %% [markdown]
# <a href="https://colab.research.google.com/github/e3la/Organizing-Information-in-Information-Agencies/blob/master/mod10_o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 10. For Further Study
# ============================
#
#  **![](https://missouri.instructure.com/courses/49361/files/8633280/download) For Further Study**
# =================================================================================================
#
# #### **Web Standards and Content Pulled from Linked Data Datastores**
#
# The following pages in this OER will help you understand how the web supports access to different kinds of content, including web content embedded into library sites from linked data datastores.
#
# [Embedding Web Content](https://missouri.instructure.com/courses/49361/pages/embedding-web-content "Embedding Web Content")
#
# [Surrogate Records and Possibilities for Enrichment](https://missouri.instructure.com/courses/49361/pages/surrogate-records-and-possibilities-for-enrichment "Surrogate Records and Possibilities for Enrichment")
#
# [Online Catalogs with Enriched Content](https://missouri.instructure.com/courses/49361/pages/online-catalogs-with-enriched-content "Online Catalogs with Enriched Content")
#
# #### **General Linked Data Information**
#
# > Berners-Lee, T. (2006). Linked data. [https://www.w3.org/DesignIssues/LinkedData](https://www.w3.org/DesignIssues/LinkedData)
#
# ##### Notes
#
# *   Berners-Lee's criteria for linked data are referenced again and again.
# *   Read the original ideas here.
#
# > Berners-Lee, T. (2009). The next web. _TED Talk._ [https://www.ted.com/talks/tim\_berners\_lee\_the\_next\_web](https://www.ted.com/talks/tim_berners_lee_the_next_web)
#
# ##### Notes
#
# *   16 minute TED Talk about a web of open, linked data.
# *   "He's building a web for open, linked data that could do for numbers what the Web did for words, pictures, video: unlock our data and reframe the way we use it together."
#
# * * *
#
# #### **Linked Data and Libraries**
#
# > Coyle, K. (2012). Taking library data from here to there. (webinar slides) _Dublin Core Metadata Initiative._ [https://www.dublincore.org/webinars/2012/taking\_library\_data\_from\_here\_to\_there/](https://www.dublincore.org/webinars/2012/taking_library_data_from_here_to_there/)
#
# ##### Notes
#
# *   Karen Coyle has been a leader in metadata innovation and in the push to move library metadata to linked open data.
# *   Scroll through the slides and pay attention to the following:
#     *   The focus on relationships—there are lots of data maps
#     *   Review of linked data characteristics
#     *   The difference between text and structured data
#     *   The importance of identifiers
#     *   Points out that library data is not unique (why not share and reuse it)
#
# > Landis, C. (2019). Linked open data in libraries. In K. J. Varnum (Ed.). _New top technologies every librarian needs to know_ (pp. 3-15). ALA Neal-Schuman. [https://radar.auctr.edu/islandora/object/auc.rwwlpub:0029](https://radar.auctr.edu/islandora/object/auc.rwwlpub:0029)
#
# ##### Notes
#
# *   If you are curious to know more about some specifics of the technology-related aspects of linked data, this chapter will provide you with plenty of ideas.
#     *   This is not "pleasure reading" -- it is, however, a well-crafted and logical approach to understanding where LAM technology is heading.
#     *   You will possibly have to put in a bit of work to read it, if these ideas are unfamiliar to you.
#     *   It will be worth it! You will not regret...
#
# > Lorimer, N. (2016). Putting the link in linked data. _ALCTS Online Learning_. [http://www.ala.org/alcts/confevents/upcoming/webinar/101916](http://www.ala.org/alcts/confevents/upcoming/webinar/101916)
#
# ##### Notes
#
# *   This webinar was hosted by ALCTS (remember ALCTS? It was a "division" of ALA, pronounced /uh-lex/ and it stood for the Association of Library Collections and Technical Services).
# *   Description: Session 2 in the series [“From MARC to BIBFRAME"](http://www.ala.org/alcts/confevents/upcoming/webinar/MARCBIBFRAME) will focus on the concept of the URI/IRI (uniform resource identifier/internationalized resource identifier) as the core of the linked data/semantic web operations. This session will focus both on the conceptual aspect of URI linking and also on the workflow and functional implications of moving from traditional authority control to URI based authority control.
#
# > Hansen, C., & Mueller, V. (2015). From MARC to BIBFRAME: An introduction. ALCTS webinar. [http://www.ala.org/alcts/confevents/upcoming/webinar/051315 ](http://www.ala.org/alcts/confevents/upcoming/webinar/051315)
#
# ##### Notes
#
# *   Watch it to understand more about BIBFRAME and also to round out your understanding of the semantic web (Web 3.0).
# *   Description: "This presentation provides an introduction to the Bibliographic Framework (BIBFRAME), a model used for expressing and connecting bibliographic data through the semantic web. Includes an overview of linked data, examples of MARC metadata expressed as BIBFRAME, and shows the possibilities of library linked data."
#
# > Samples, J., & Bigelow, I. (2019). A shared approach to BIBFRAME implementation. ALCTS webinar. [http://www.ala.org/alcts/confevents/upcoming/webinar/052219 ](http://www.ala.org/alcts/confevents/upcoming/webinar/052219)
#
# ##### Notes
#
# *   Another ALCTS webinar. This one looks at a particular implementaiton of BIBFRAME and linked data technologies in a library environment. [Share-VDE](https://www.share-vde.org/sharevde/clusters?l=en). Share-VDE (SHARE Virtual Discovery Environment) is a BIBFRAME discovery product developed by the LD4P (Linked Data for Production) and includes a number of research libraries and others.
#
# * * *
#
# #### **OCLC and Linked Data**
#
# > OCLC. (n.d.). Linked data (website) [https://www.oclc.org/research/areas/data-science/linkeddata.html](https://www.oclc.org/research/areas/data-science/linkeddata.html)
#
# ##### Notes
#
# *   Here you will find links to information and to some of OCLC's linked data content.
# *   Note that OCLC indicates that Schema.org is being used in its projects.
# *   In general, OCLC's goal is to push library metadata out for reuse by others.
#
# * * *
#
# #### **Wikidata—as noted above, "a collaboratively edited structured dataset"**
#
# > Wikidata. (2020). In _Wikipedia._ [https://en.wikipedia.org/wiki/Wikidata](https://en.wikipedia.org/wiki/Wikidata)
#
# ##### Notes
#
# *   Wikidata record: Robert Darnton. [https://www.wikidata.org/wiki/Q964180](https://www.wikidata.org/wiki/Q964180)
# *   See what information is included in a Wikidata record for a person. Note the sources for the information. Note that the sources of the data elements are included.
#
# > Veen, T. van. (2019). Wikidata: From “an” identifier to “the” identifier. _Information Technology and Libraries, 38_(2), 72–81. [https://doi.org/10.6017/ital.v38i2.10886](https://doi.org/10.6017/ital.v38i2.10886)  [(Links to an external site.)](https://escholarship.umassmed.edu/neirug/2019/program/5/)
#
# ##### Notes
#
# *   Wikidata has captured the imagination of information professionals aroudn the world, and is being considered as a solution to the problem of too many vocabularies.
# *   This article presents an interesting point of view in regards to some of the problems with linked data and a the web of data that it requires.
#
# > Britton A. (2019). Wikidata and Institutional Repositories. Northeast Institutional Repository Day. [https://escholarship.umassmed.edu/neirug/2019/program/5/](https://escholarship.umassmed.edu/neirug/2019/program/5/)
#
# ##### Notes
#
# *   "Wikidata is a free and open knowledge base that can be read and edited by both humans and machines. It is multilingual, structured, and contains more than 56 million data items. Authors, works, repositories, policies, and infrastructure can be represented via Wikidata. This presentation will give a quick overview of Wikidata and how it can extend the reach of your repository. It will also share tips on getting started, scaling up with tools like OpenRefine and QuickStatements, and creating dynamic visualizations with web services like Scholia."
#
# * * *
#
# #### **Schema.org—a vocabulary used to structure data on websites**
#
# > Schema.org. (2020). In _Wikipedia_. [https://en.wikipedia.org/w/index.php?title=Schema.org&oldid=974901200](https://en.wikipedia.org/w/index.php?title=Schema.org&oldid=974901200)
#
# > Wallis, R. (2015). Schema.org, Part 1. Fit for a bibliographic purpose. (webinar)
# > [Part 1 - Fit For a Bibliographic Purpose (Richard Wallis)](https://www.youtube.com/watch?v=ZiijJj1v1bQ) [![](/images/play_overlay.png)](https://www.youtube.com/watch?v=ZiijJj1v1bQ)
#
# ##### Notes
#
# *   "Richard Wallis, traces the history of the Schema.org vocabulary, plus its applicability to the bibliographic domain. He will share the background to, and activities of, the Schema Bib Extend W3C Community Group he chairs; why it was set up; how it approached the creation of bibliographic extension proposals; and how those proposals were shaped. He will then review the current status of the vocabulary and the recent introduction of the bib.schema.org and auto.schema.org extensions."
#
# * * *
#
# #### **Miscellaneous**
#
# > Deng, S. (2018). Linked data in the library & OpenRefine. Stay Savvy with Scholarly Communication Brown Bag Lunch, University of Central Florida Libraries, August 9, 2018. (presentation slides) [https://stars.library.ucf.edu/cgi/viewcontent.cgi?article=1786&context=ucfscholar](https://stars.library.ucf.edu/cgi/viewcontent.cgi?article=1786&context=ucfscholar)
#
# ##### Notes
#
# *   Presentation slides only, but the information will look familiar.
# *   Includes information about linked data concepts and some library projects. Also, covers a case study about adding linked data vocabularies to the University of Central Florida digital repositories.
